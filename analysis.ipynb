# %% [markdown]
# # Analysis
# ## Plotting the Data
# ### premise
#
# - streams represents how successful a song is

# %% [markdown]
# ### imports

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Daten/cleaned_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            435 non-null    object
#  1   artist(s)_name        435 non-null    object
#  2   artist_count          435 non-null    int64
#  3   released_year         435 non-null    int64
#  4   released_month        435 non-null    int64
#  5   released_day          435 non-null    int64
#  6   in_spotify_playlists  435 non-null    int64
#  7   in_spotify_charts     435 non-null    int64
#  8   streams               435 non-null    float64
#  9   in_apple_playlists    435 non-null    int64
#  10  in_apple_charts       435 non-null    int64
#  11  in_deezer_playlists   435 non-null    int64
#  12  in_deezer_charts      435 non-null    int64
#  13  in_shazam_charts      435 non-null    int64
#  14  key                   435 non-null    object
# ...

# %% [markdown]
# ### Plotting the scores of danceability, ... against streams

# %%
columns_to_plot = ['danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%', 'artist_count']

fig, axes = plt.subplots(3, 3, figsize=(16, 12))
axes = axes.flatten()

for i, column in enumerate(columns_to_plot):
    plt.sca(axes[i])
    
    scatter = plt.scatter(df[column], df['streams'], c=df[column], alpha=0.5)
    
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Streams', fontsize=12)
    plt.title(f'Streams vs. {column}', fontsize=14)
    plt.grid(True)
    plt.colorbar(scatter, label=column)

for j in range(len(columns_to_plot), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Key against Streams

# %%
palette = sns.color_palette("Set2", len(df['key'].unique()))

sns.catplot(x="key", y="streams", data=df, aspect=2)
plt.xlabel("Keys", fontsize=20)
plt.ylabel("Streams", fontsize=20)
plt.show()

# %%
palette = sns.color_palette("Set2", len(df['key'].unique()))

sorted_keys = sorted(df['key'].unique())
plt.figure(figsize=(12, 6))
sns.boxplot(y="key", x="streams", data=df, order=sorted_keys)
plt.xlabel("Streams", fontsize=20)
plt.ylabel("Keys", fontsize=20)
plt.title("Box Plot of Streams by Keys", fontsize=20)
plt.show()

# %% [markdown]
# ### Countplot of Keys

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x="key", data=df, order = df['key'].value_counts().index)
plt.xlabel("Keys", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Count of Each Key", fontsize=16)
plt.show()

# %% [markdown]
# ### charts/playlists against streams

# %%
columns_to_plot = ['in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts']

fig, axes = plt.subplots(3, 3, figsize=(16, 12))
axes = axes.flatten()

for i, column in enumerate(columns_to_plot):
    plt.sca(axes[i])
    
    scatter = plt.scatter(df[column], df['streams'], c=df[column], alpha=0.5)
    
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Streams', fontsize=12)
    plt.title(f'Streams vs. {column}', fontsize=14)
    plt.grid(True)
    plt.colorbar(scatter, label=column)

for j in range(len(columns_to_plot), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
